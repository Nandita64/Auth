# %% [markdown]
# <a href="https://colab.research.google.com/github/Nandita64/Auth/blob/main/Assignment_1_DNN_2025AE05057.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy pandas matplotlib

# %%
import pandas
import numpy
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df=pandas.read_csv('/content/diamonds.csv')
print(df)
print(df.values)
print(df.head)
# Out:
#        Unnamed: 0  carat        cut color  ... price     x     y     z
# 0               1   0.23      Ideal     E  ...   326  3.95  3.98  2.43
# 1               2   0.21    Premium     E  ...   326  3.89  3.84  2.31
# 2               3   0.23       Good     E  ...   327  4.05  4.07  2.31
# 3               4   0.29    Premium     I  ...   334  4.20  4.23  2.63
# 4               5   0.31       Good     J  ...   335  4.34  4.35  2.75
# ...           ...    ...        ...   ...  ...   ...   ...   ...   ...
# 53935       53936   0.72      Ideal     D  ...  2757  5.75  5.76  3.50
# 53936       53937   0.72       Good     D  ...  2757  5.69  5.75  3.61
# 53937       53938   0.70  Very Good     D  ...  2757  5.66  5.68  3.56
# 53938       53939   0.86    Premium     H  ...  2757  6.15  6.12  3.74
# 53939       53940   0.75      Ideal     D  ...  2757  5.83  5.87  3.64
#
# [53940 rows x 11 columns]
# [[1 0.23 'Ideal' ... 3.95 3.98 2.43]
#  [2 0.21 'Premium' ... 3.89 3.84 2.31]
# ...

# %%
# clean the data
df = df.drop(columns=["Unnamed: 0"])

# %%
# defining X anf y
X = df.drop(columns=["price"])
y = df["price"].values

# %%
#Encoding
X = pandas.get_dummies(X, drop_first=True)

# %%
#Scalar
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
#training 80 and testing 20
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

class MLP:
    def __init__(self, layers):
        self.layers = layers
        self.params = {}

    def initialize_parameters(self):
        for i in range(1, len(self.layers)):
            self.params['b' + str(i)] = numpy.zeros((1, self.layers[i]))

# %%
#initialize weights
n_features = X.shape[1]

W = numpy.random.randn(n_features, 1) * 0.01


#Prediction
y_pred = X @ W + b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_232/72275040.py in <cell line: 0>()
#       5
#       6 #initialize bias
# ----> 7 b = numpy.zeros((1, number_of_neurons))
#       8 #Prediction
#       9 y_pred = X @ W + b
#
# NameError: name 'number_of_neurons' is not defined
